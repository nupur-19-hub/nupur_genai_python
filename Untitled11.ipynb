# %% [markdown]
# <a href="https://colab.research.google.com/github/nupur-19-hub/nupur_genai_python/blob/nupur_genai_python/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#decision tree
import pandas as pd
df=pd.read_csv("/content/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Task
# Analyze the dataframe "iris.csv" by showing the first few rows and summary statistics, checking for missing values, plotting distributions of features using histograms, boxplots, and pairplots, and generating a correlation heatmap.

# %% [markdown]
# ## Show the first few rows and summary statistics of the dataframe.
#
# ### Subtask:
# Display the initial rows of the dataframe and provide descriptive statistics for each column.

# %% [markdown]
# **Reasoning**:
# Display the first few rows and descriptive statistics of the dataframe as requested by the instructions.

# %%
display(df.head())
display(df.describe())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# ...

# %% [markdown]
# ## Check for missing values in the dataframe.
#
# ### Subtask:
# Identify and quantify any missing values present in the dataframe.

# %% [markdown]
# **Reasoning**:
# Identify and quantify any missing values present in the dataframe by checking for null values in each column and summing them up.

# %%
missing_values = df.isnull().sum()
print("Missing values per column:")
print(missing_values)
# Out:
# Missing values per column:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ## Plot distributions of the features using histograms, boxplots, and pairplots.
#
# ### Subtask:
# Visualize the distribution of each feature using histograms and boxplots, and explore relationships between pairs of features using pairplots.

# %% [markdown]
# **Reasoning**:
# Visualize the distribution of each numerical feature using histograms and boxplots, and explore relationships between pairs of numerical features using pairplots, coloring by 'Species'.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create histograms for each numerical column
df.hist(figsize=(10, 8))
plt.suptitle('Histograms of Iris Dataset Features', y=1.02, fontsize=16)
plt.tight_layout()
plt.show()

# Create boxplots for each numerical column
plt.figure(figsize=(10, 8))
sns.boxplot(data=df.drop('Id', axis=1))
plt.title('Boxplots of Iris Dataset Features', fontsize=16)
plt.ylabel('Measurement (cm)')
plt.tight_layout()
plt.show()

# Generate a pairplot of the DataFrame, colored by 'Species'
sns.pairplot(df.drop('Id', axis=1), hue='Species')
plt.suptitle('Pairplot of Iris Dataset Features by Species', y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# ## Generate a correlation heatmap to visualize the relationships between features.
#
# ### Subtask:
# Generate a correlation heatmap to visualize the relationships between features.

# %% [markdown]
# **Reasoning**:
# The error indicates that the 'Species' column, which is a string type, is being included in the correlation calculation. The correlation can only be calculated on numerical columns. I need to exclude the 'Species' column as well as the 'Id' column before calculating the correlation matrix.

# %%
correlation_matrix = df.drop(['Id', 'Species'], axis=1).corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Iris Dataset Features', fontsize=16)
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The dataset contains 150 entries and 5 columns: `Id`, `SepalLengthCm`, `SepalWidthCm`, `PetalLengthCm`, and `PetalWidthCm`, along with a `Species` column.
# *   There are no missing values in the dataset.
# *   Histograms and boxplots show the distributions of the numerical features.
# *   Pairplots reveal the relationships between pairs of features, with different species often showing distinct clusters based on these relationships.
# *   The correlation heatmap indicates the strength and direction of linear relationships between numerical features. Notably, `PetalLengthCm` and `PetalWidthCm` show a strong positive correlation (around 0.96), and both are also strongly positively correlated with `SepalLengthCm`. `SepalWidthCm` shows weaker correlations with the other features.
#
# ### Insights or Next Steps
#
# *   The strong correlations observed between `PetalLengthCm`, `PetalWidthCm`, and `SepalLengthCm` suggest these features are highly informative for distinguishing between iris species.
# *   Further analysis could involve applying machine learning classification algorithms to predict the iris species based on these features, leveraging the insights gained from the visualizations and correlations.

# %% [markdown]
# new

# %% [markdown]
# ## Prepare Data for Modeling
#
# ### Subtask:
# Split the data into features and target, encode the categorical target variable, and split the data into training and testing sets.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Separate features (X) and target (y)
X = df.drop(['Id', 'Species'], axis=1)
y = df['Species']

# Encode categorical labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split data into training and testing sets (e.g., 80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (120, 4)
# Shape of X_test: (30, 4)
# Shape of y_train: (120,)
# Shape of y_test: (30,)

# %% [markdown]
# ## Train a Decision Tree Classifier
#
# ### Subtask:
# Train a Decision Tree Classifier using `sklearn.tree.DecisionTreeClassifier` and fit the model on the training data.

# %%
from sklearn.tree import DecisionTreeClassifier

# Initialize the Decision Tree Classifier
decision_tree_model = DecisionTreeClassifier(random_state=42)

# Fit the model on the training data
decision_tree_model.fit(X_train, y_train)

print("Decision Tree Classifier trained successfully.")
# Out:
# Decision Tree Classifier trained successfully.

# %% [markdown]
# ## Visualize the decision tree using `sklearn.tree.plot tree()`.
#
# ### Subtask:
# Visualize the trained Decision Tree Classifier.

# %% [markdown]
# **Reasoning**:
# Visualize the trained Decision Tree Classifier using `plot_tree` including feature names, class names, filled nodes, and rounded boxes.

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Create figure and axes for the plot
plt.figure(figsize=(15, 10))

# Visualize the trained decision tree
plot_tree(decision_tree_model,
          feature_names=X.columns.tolist(),
          class_names=label_encoder.classes_,
          filled=True,
          rounded=True)

plt.title('Decision Tree Visualization', fontsize=16)
plt.show()

# %% [markdown]
# **Reasoning**:
# Calculate and visualize the feature importances of the trained decision tree model.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Get feature importances
importances = decision_tree_model.feature_importances_

# Create a DataFrame for better visualization
feature_importances = pd.DataFrame({'feature': X.columns, 'importance': importances})

# Sort features by importance
feature_importances = feature_importances.sort_values('importance', ascending=False)

# Visualize feature importances
plt.figure(figsize=(10, 6))
plt.bar(feature_importances['feature'], feature_importances['importance'])
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Feature Importances from Decision Tree')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The decision tree model was successfully trained and visualized using both `sklearn.tree.plot_tree` and `export_graphviz`.
# *   Feature importances were calculated and visualized, highlighting the relative contribution of each feature to the model's predictions.
#
# ### Insights or Next Steps
#
# *   Analyze the feature importances to understand which features are most predictive of the target variable.
# *   Evaluate the performance of the decision tree model using appropriate metrics (e.g., accuracy, precision, recall) to determine its effectiveness.

# %% [markdown]
# ## Evaluate the Decision Tree Model
#
# ### Subtask:
# Make predictions on the test data, evaluate the model using accuracy score, confusion matrix, and classification report, and perform cross-validation for robustness.

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns

# Make predictions on the test set
y_pred = decision_tree_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred, target_names=label_encoder.classes_)
matrix = confusion_matrix(y_test, y_pred)

print(f"Accuracy on the test set: {accuracy:.4f}")
print("\nClassification Report:")
print(report)

print("\nConfusion Matrix:")
plt.figure(figsize=(8, 6))
sns.heatmap(matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Perform cross-validation
cv_scores = cross_val_score(decision_tree_model, X, y_encoded, cv=5) # Using 5 folds

print("\nCross-validation scores (5-fold):")
print(cv_scores)
print(f"Mean cross-validation accuracy: {cv_scores.mean():.4f}")
# Out:
# Accuracy on the test set: 0.9333
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.90      0.90      0.90        10
#  Iris-virginica       0.90      0.90      0.90        10
#
#        accuracy                           0.93        30
#       macro avg       0.93      0.93      0.93        30
#    weighted avg       0.93      0.93      0.93        30
#
#
# Confusion Matrix:
# Cross-validation scores (5-fold):
# [0.96666667 0.96666667 0.9        0.93333333 1.        ]
# Mean cross-validation accuracy: 0.9533

# %% [markdown]
# ## Predict Species for a New Input
#
# ### Subtask:
# Take a new input (e.g., sepal length, width, petal length, width) and use the trained model to predict the species.

# %%
# Example new input (replace with your desired values)
new_input = [[2.1, 5, 6.3, 3.4]] # Example for Iris-virginica

# Make a prediction
predicted_species_encoded = decision_tree_model.predict(new_input)

# Decode the predicted label back to the original species name
predicted_species = label_encoder.inverse_transform(predicted_species_encoded)

print(f"The predicted species for the input {new_input[0]} is: {predicted_species[0]}")
# Out:
# The predicted species for the input [2.1, 5, 6.3, 3.4] is: Iris-virginica
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
